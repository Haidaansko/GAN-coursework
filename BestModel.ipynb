# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pathlib
import re
from google.colab import drive
drive.mount('/content/gdrive')
ROOT_PATH = "gdrive/My Drive/data/gan"
regexp = re.compile(r'v1_(?P<name>[a-z]*)_train.csv')
rp = pathlib.Path(ROOT_PATH)
particles = list(map(lambda x: regexp.findall(x.name)[0], rp.iterdir()))
for particle, path in zip(particles, rp.iterdir()):
	exec(f'df_{particle} = pd.read_csv(path.absolute())')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df_pion.head()
# Out:
#       TrackPt        TrackP  NumLongTracks  ...  RichDLLp   RichDLLe  TrackEta
# 0  292.449890   5383.890137           95.0  ...   -4.8921  -8.547900  3.605282
# 1  537.121704   5875.910156           23.0  ...  -24.2808 -30.771500  3.083443
# 2  996.601135   5114.390137           61.0  ...  -30.7045 -53.311001  2.318979
# 3  514.304382  20254.830078           72.0  ...   -1.6131  -6.002100  4.366319
# 4  303.679565   3026.860107           43.0  ...   -0.4927 -17.817699  2.989929
#
# [5 rows x 10 columns]

# %%
df_pion.describe()
# Out:
#             TrackPt        TrackP  ...      RichDLLe      TrackEta
# count  1.000006e+06  1.000006e+06  ...  1.000006e+06  1.000006e+06
# mean   6.108592e+02  1.165775e+04  ... -4.464395e+01  3.508481e+00
# std    6.110336e+02  1.537453e+04  ...  1.559057e+02  7.593682e-01
# min    5.804594e+00  1.120040e+03  ... -9.990000e+02  1.539339e+00
# 25%    2.732105e+02  3.932927e+03  ... -3.033440e+01  2.923832e+00
# 50%    4.434661e+02  6.965105e+03  ... -1.576320e+01  3.505969e+00
# 75%    7.377449e+02  1.340857e+04  ... -5.094025e+00  4.095446e+00
# max    6.542564e+04  1.067609e+06  ...  9.727790e+01  8.133177e+00
#
# [8 rows x 10 columns]

# %%
df_kaon.head()
# Out:
#        TrackPt        TrackP  NumLongTracks  ...   RichDLLp  RichDLLe  TrackEta
# 0   733.720825   7811.620117           40.0  ...   5.395000   -6.4719  3.056173
# 1   766.389587  13805.900391           29.0  ...  32.001301  -11.0133  3.583537
# 2   454.289093   4635.049805           32.0  ...  17.493500   -7.7980  3.013405
# 3  1054.564331   4333.899902           26.0  ...  19.676600  -11.6452  2.091345
# 4  1975.175537  24745.910156           57.0  ...  10.397500    0.0172  3.219554
#
# [5 rows x 10 columns]

# %%
df_kaon.describe()
# Out:
#              TrackPt        TrackP  ...       RichDLLe       TrackEta
# count  999993.000000  9.999930e+05  ...  999993.000000  999993.000000
# mean      917.169911  1.720783e+04  ...     -20.286071       3.480167
# std       870.250223  2.147142e+04  ...     123.262531       0.772688
# min        19.675070  1.143810e+03  ...    -999.000000       1.541899
# 25%       406.408234  5.646150e+03  ...      -8.592300       2.873515
# 50%       674.999756  1.041678e+04  ...      -2.710600       3.476622
# 75%      1129.237061  2.039669e+04  ...      -0.032200       4.085278
# max     80601.171875  1.063457e+06  ...      91.978104       5.945569
#
# [8 rows x 10 columns]

# %%
df_muon.head()
# Out:
#        TrackPt        TrackP  NumLongTracks  ...    RichDLLp    RichDLLe  TrackEta
# 0  1994.030762  25978.289062           47.0  ...  -79.582802   -8.966200  3.258774
# 1  1627.580444   6140.810059           66.0  ...  -23.658199  -17.655899  2.002966
# 2  2714.667725  18381.529297           72.0  ...   13.134600    2.585600  2.600326
# 3   847.640381  12456.349609           60.0  ...    3.355200    0.127200  3.379517
# 4   140.604111   5683.930176           37.0  ... -999.000000 -999.000000  4.392444
#
# [5 rows x 10 columns]

# %%
df_muon.describe()
# Out:
#             TrackPt        TrackP  ...      RichDLLe      TrackEta
# count  1.000001e+06  1.000001e+06  ...  1.000001e+06  1.000001e+06
# mean   1.977057e+03  3.019452e+04  ... -1.911727e+01  3.233263e+00
# std    3.133910e+03  4.595246e+04  ...  1.168489e+02  7.539622e-01
# min    8.310864e+00  1.109380e+03  ... -9.990000e+02  1.542635e+00
# 25%    6.058935e+02  6.458260e+03  ... -9.533900e+00  2.627582e+00
# 50%    1.391642e+03  1.544247e+04  ... -1.106900e+00  3.185104e+00
# 75%    2.587355e+03  3.588513e+04  ...  6.005000e-01  3.796945e+00
# max    5.782048e+05  4.750951e+06  ...  9.389430e+01  7.281530e+00
#
# [8 rows x 10 columns]

# %%
df_proton.head()
# Out:
#        TrackPt        TrackP  NumLongTracks  ...   RichDLLp   RichDLLe  TrackEta
# 0   463.939606   3072.429932           58.0  ...   2.547200 -18.342199  2.577867
# 1   681.318787   1956.859985           63.0  ...   0.000000 -34.756199  1.716429
# 2   428.073242   2778.239990            6.0  ...   3.948300 -21.707399  2.557437
# 3  2067.380615  37160.468750           45.0  ...  50.999802  -0.176800  3.581336
# 4   392.244202   3534.719971           12.0  ...   8.237600 -16.298700  2.888559
#
# [5 rows x 10 columns]

# %%
df_proton.describe()
# Out:
#              TrackPt        TrackP  ...       RichDLLe       TrackEta
# count  999994.000000  9.999940e+05  ...  999994.000000  999994.000000
# mean      951.632676  1.767020e+04  ...     -19.281610       3.425502
# std       811.404172  2.220218e+04  ...     119.239851       0.777763
# min         8.959981  1.164830e+03  ...    -999.000000       1.540509
# 25%       434.631180  5.529433e+03  ...      -8.774875       2.804658
# 50%       730.671417  1.045704e+04  ...      -2.299200       3.418101
# 75%      1217.480927  2.109436e+04  ...       0.190500       4.030180
# max     37309.593750  1.347937e+06  ...     122.141403       7.627482
#
# [8 rows x 10 columns]

# %%
df_electron.head()
# Out:
#        TrackPt         TrackP  NumLongTracks  ...  RichDLLp  RichDLLe  TrackEta
# 0  2900.960449  146387.968750           17.0  ...  -13.6412    0.1041  4.614268
# 1  1039.614624   38299.628906           62.0  ...    0.2746    0.1979  4.299553
# 2   748.570251   35151.000000           38.0  ...    5.8671    1.6676  4.542277
# 3    80.008705    4731.169922           26.0  ... -999.0000 -999.0000  4.772868
# 4   999.364868   38570.808594           49.0  ...  -24.8507   -0.7465  4.346110
#
# [5 rows x 10 columns]

# %%
df_electron.describe()
# Out:
#             TrackPt        TrackP  ...      RichDLLe      TrackEta
# count  1.000004e+06  1.000004e+06  ...  1.000004e+06  1.000004e+06
# mean   7.744103e+02  1.200671e+04  ... -4.223394e+01  3.457996e+00
# std    1.022024e+03  1.880961e+04  ...  2.525838e+02  7.641018e-01
# min    6.317903e+00  1.163420e+03  ... -9.990000e+02  1.558910e+00
# 25%    2.031424e+02  3.426308e+03  ...  1.263400e+00  2.864774e+00
# 50%    4.200316e+02  6.069970e+03  ...  1.330250e+01  3.464443e+00
# 75%    9.365944e+02  1.257874e+04  ...  3.406803e+01  4.055261e+00
# max    4.021005e+04  1.236918e+06  ...  2.209829e+02  6.960579e+00
#
# [8 rows x 10 columns]

# %%
df_ghost.head()
# Out:
#       TrackPt        TrackP  NumLongTracks  ...    RichDLLp    RichDLLe  TrackEta
# 0  494.463684   1923.849976           12.0  ...    0.000000  -35.542198  2.034818
# 1   81.083633   4240.009766           63.0  ... -999.000000 -999.000000  4.649895
# 2  450.273376  14234.519531           39.0  ...   15.703200   -5.172300  4.146467
# 3  563.783081   3682.260010           26.0  ...   18.708099   -5.129300  2.563847
# 4  117.248886   2202.000000           45.0  ...    0.000000   -9.898700  3.625260
#
# [5 rows x 10 columns]

# %%
df_ghost.describe()
# Out:
#              TrackPt        TrackP  ...       RichDLLe       TrackEta
# count  999995.000000  9.999950e+05  ...  999995.000000  999995.000000
# mean      385.562737  8.576308e+03  ...    -159.754090       3.868309
# std      2120.557016  3.075479e+04  ...     361.702544       0.757245
# min         0.451171  1.118740e+03  ...    -999.000000       1.539133
# 25%       113.097980  2.821880e+03  ...     -20.574200       3.374475
# 50%       205.899185  4.601630e+03  ...      -5.545200       3.930078
# 75%       404.583603  8.632430e+03  ...       1.463550       4.411137
# max    633395.437500  4.969893e+06  ...     179.980103      10.429631
#
# [8 rows x 10 columns]

# %% [markdown]
# Input variables are:
# *   `TrackP` – full momentum of the particle
# *   `TrackPt` – length of the momentum projection to the XY plane
# *   `TrackEta` – track [pseudorapidity](https://en.wikipedia.org/wiki/Pseudorapidity)
# *   `NumLongTracks` – number of reconstructed tracks in current event
#
# Please note that among P, Pt and ETA there are only **two** independant variables.
#
#
# The variables to predict are:
#
# *   `RichDLLbt`
# *   `RichDLLk`
# *   `RichDLLmu`
# *   `RichDLLp`
# *   `RichDLLe`
#
#
# There's also one additional variable:
#
# *   `MCParticleType` – particle [PDG code](http://pdg.lbl.gov/2007/reviews/montecarlorpp.pdf)

# %% [markdown]
# One can see there's a peak of outliers at the left handside of the plot. Let's not bother about it so far.

# %%
df_kaon_normalized = (df_kaon - df_kaon.values.mean(axis=0)) / df_kaon.values.std(axis=0)
df_kaon_normalized.head()
# Out:
#     TrackPt    TrackP  NumLongTracks  ...  RichDLLp  RichDLLe  TrackEta
# 0 -0.210800 -0.437615      -0.413826  ...  0.079074  0.112071 -0.548725
# 1 -0.173261 -0.158440      -0.889474  ...  0.290724  0.075228  0.133780
# 2 -0.531894 -0.585559      -0.759752  ...  0.175316  0.101313 -0.604075
# 3  0.157879 -0.599585      -1.019196  ...  0.192682  0.070101 -1.797391
# 4  1.215749  0.351075       0.321267  ...  0.118868  0.164716 -0.337281
#
# [5 rows x 10 columns]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers as L
from functools import partial
import numpy as np
import pandas as pd


def get_tf_dataset(dataset, batch_size):
    N_EXAMPLES = len(dataset)
    shuffler = tf.contrib.data.shuffle_and_repeat(N_EXAMPLES)
    dataset_tf = tf.data.Dataset.from_tensor_slices(dataset)
    suffled_ds = shuffler(dataset_tf)
    
    dataset_final = suffled_ds.batch(batch_size).prefetch(1)
    iterator = tf.compat.v1.data.make_one_shot_iterator(dataset_final)
    return iterator.get_next()

def sample_noise_batch(bsize, dim):
    return np.random.normal(size=(bsize, dim)).astype('float32')

def normalize(df):
    means = df.values.mean(axis=0)
    stds = df.values.std(axis=0)
    df_norm = (df - means) / stds
    df_norm[df_norm.isna()] = 0
    return df_norm, means, stds


class Model:
    def fit(self, X, Y):
        sess = tf.InteractiveSession()
        
        TOTAL_ITERATIONS = int(5e3)
        DISCRIMINATOR_ITERATIONS = 5
        x_dim, y_dim = 3, 5
        noise_dim = 3
        train_batch_size = 1000
        disc_lr = 1e-3
        
        X = X[['TrackP', 'TrackEta', 'NumLongTracks']]
        X, _, _ = normalize(X)
        
        gen_activation = tf.keras.activations.elu
        with tf.name_scope("Generator"):
            generator = Sequential(name="Generator")
            generator.add(L.InputLayer([x_dim + noise_dim], name='noise'))
            for i in range(5):
                generator.add(L.Dense(128, activation=gen_activation))
            generator.add(L.Dense(y_dim))

            
        disc_activation = partial(tf.keras.activations.relu, alpha=0.3)
        with tf.name_scope("Discriminator"):
            discriminator = Sequential(name="Discriminator")
            discriminator.add(L.InputLayer([x_dim + y_dim]))
            for i in range(5):
                discriminator.add(L.Dense(128, activation=disc_activation))         
            discriminator.add(L.Dense(2, activation=tf.nn.log_softmax))

        
        real_data = get_tf_dataset(pd.concat([X, Y], axis=1), train_batch_size)
        real_data = tf.dtypes.cast(real_data, tf.float32)
        noise_batch_size = tf.placeholder(tf.int32, shape=[], name="noise_batch_size")
        noise = tf.random_normal([noise_batch_size, noise_dim], dtype=tf.float32, name="noise")
        X_batch = get_tf_dataset(X, train_batch_size)
        X_batch = tf.dtypes.cast(X_batch, tf.float32)
        generated_data = tf.concat(
            [
                X_batch, 
                generator(tf.concat([X_batch, noise], axis=1))
            ], axis=1)
        logp_real = discriminator(real_data)
        logp_gen = discriminator(generated_data)
        
        
        
        disc_loss = -tf.reduce_mean(logp_real[:,1] + logp_gen[:,0])
        disc_optimizer = tf.train.GradientDescentOptimizer(disc_lr).minimize(
                disc_loss, var_list=discriminator.trainable_weights)
        
        gen_loss = -tf.reduce_mean(logp_gen[:,1])
        tf_iter = tf.Variable(initial_value=0, dtype=tf.int32)
        gen_lr = tf.train.exponential_decay(5e-4, tf_iter, 150, 0.98)
        gen_optimizer = tf.group(
            tf.train.AdamOptimizer(gen_lr).minimize(
                gen_loss, var_list=generator.trainable_weights),
            tf.assign_add(tf_iter, 1))
        
        learning_summary = tf.summary.merge([
            tf.summary.scalar("disc_loss", disc_loss),
            tf.summary.scalar("gen_loss", gen_loss),
        ])

        sess.run(tf.global_variables_initializer())
        
        for epoch in range(TOTAL_ITERATIONS):
            for i in range(DISCRIMINATOR_ITERATIONS):
                sess.run(disc_optimizer, {noise_batch_size: train_batch_size})
            summary, _, _ = sess.run(
                [learning_summary, gen_optimizer, tf_iter], 
                {noise_batch_size: train_batch_size})

        self.generator = generator
        self.y_cols = Y.columns
        self.noise_dim = noise_dim
        self.sess = sess
    
        
            
    def predict(self, X, normalized=False):
        X = X[['TrackP', 'TrackEta', 'NumLongTracks']]
        X, _, _ = normalize(X)
        noise = sample_noise_batch(bsize=len(X), dim=self.noise_dim)
        Y_pred = self.generator.predict(np.concatenate([X, noise], axis=1))
        return pd.DataFrame(Y_pred, columns=self.y_cols)

# %%
from scipy.stats import ks_2samp

def score_func(sample1, sample2, n_slices=100):
    score = 0
    cols = sample1.columns
    w_normal = np.random.normal(size=(n_slices, len(cols)))
    reference = sample1.values
    
    #prediction = sample2.values
    prediction = sample2.values
    for k in range(n_slices):
        score = max(score,
                    ks_2samp(
                        np.sum(w_normal[k] * reference, axis=1),
                        np.sum(w_normal[k] * prediction, axis=1)
                    )[0]
                   )
    return score

# %%
from sklearn.model_selection import train_test_split

train_ids, test_ids = train_test_split(np.arange(len(df_kaon)), test_size=0.2, random_state=int(time()))
X, Y = df_kaon[x_cols].iloc[train_ids], df_kaon[y_cols].iloc[train_ids]
X_test, Y_test = df_kaon[x_cols].iloc[test_ids], df_kaon[y_cols].iloc[test_ids]

# %%
model = Model()
model.fit(X, Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch = 0, time 1.56353
# predictions generated, time 8.03117
# score = 0.927899, time 2.73738
#
# epoch = 1000, time 50.4091
# predictions generated, time 3.12789
# score = 0.312179, time 2.9385
#
# epoch = 2000, time 50.3329
# predictions generated, time 3.10918
# score = 0.164527, time 2.92167
#
# epoch = 3000, time 51.3629
# predictions generated, time 3.35445
# score = 0.0648758, time 2.95302
#
# epoch = 4000, time 50.2842
# predictions generated, time 3.13747
# score = 0.0773885, time 2.9217

# %%
Y_pred = model.predict(X_test)
score_func(Y_pred, Y_test)
# Out:
# 0.07376536882684415

# %%
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(8, 20))
i = 0
for i, col in enumerate(Y_test.columns):
    _, bins, _ = axes[i].hist(
        Y_test[col], bins=400, density=True, label='test'      )
    _, _, _ = axes[i].hist(
        Y_pred[col], bins=bins, density=True, label='prediction', alpha=0.7)
    axes[i].legend()
    axes[i].set_xlabel(f'kaon {col}')
    axes[i].set_ylabel('prob')
    axes[i].set_xlim(left=-100)
fig.show()

# %%
import matplotlib.colors as colors
def my2d_hist(df, Y_pred, x_par_name, y_par_name):

    not_outlier = df[y_par_name] > -500

    bins = np.linspace(
            start=min(df[y_par_name][not_outlier].min(), Y_pred[y_par_name].min()), 
            stop =max(df[y_par_name][not_outlier].max(), Y_pred[y_par_name].max()), 
            num=201
        )

    fig, (ax_real, ax_fake) = plt.subplots(
                                        nrows=1,
                                        ncols=2,
                                        figsize=(15, 6)
                                    )

    _, bins_x, bins_y, img_real = \
        ax_real.hist2d(
                x=df[x_par_name],
                y=df[y_par_name],
                bins=(100, bins),
                cmap='seismic',
                norm=colors.LogNorm()
            )
    _, _, _, img_fake = \
        ax_fake.hist2d(
                x=df[x_par_name],
                y=Y_pred[y_par_name],
                bins=(bins_x, bins_y),
                cmap='seismic',
                norm=colors.LogNorm()
            )


    plt.colorbar(img_real, ax=ax_real)
    ax_real.set_xlabel(x_par_name)
    ax_real.set_ylabel(y_par_name)
    ax_real.set_title('Real kaon')
    plt.colorbar(img_fake, ax=ax_fake)
    ax_fake.set_xlabel(x_par_name)
    ax_fake.set_ylabel(y_par_name)
    ax_fake.set_title('Fake kaon')

    fig.tight_layout()

# %%
from itertools import product

df = pd.concat([X_test, Y_test], axis=1)
for x, y in product(X.columns, Y.columns):
    my2d_hist(df, Y_pred, x, y)
